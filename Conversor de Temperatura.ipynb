# %%
from tkinter import *

# %%
class Janela:
    def __init__(self, Tk):
        Tk.resizable(width = True, height = True)
        self.frame1 = Frame(Tk)
        self.frame2 = Frame(Tk)
        self.frame3 = Frame(Tk)
        self.frame4 = Frame(Tk)
        self.frame5 = Frame(Tk)
        self.frame6 = Frame(Tk)
        self.frame7 = Frame(Tk)
        self.frame8 = Frame(Tk)
        self.frame9 = Frame(Tk)
        self.frame10 = Frame(Tk)
        self.frame11 = Frame(Tk)
        self.frame12 = Frame(Tk)
        self.frame13 = Frame(Tk)
        self.frame14 = Frame(Tk)
        self.frame15 = Frame(Tk)
        self.frame16 = Frame(Tk)
        self.frame17 = Frame(Tk)
        self.frame18 = Frame(Tk)
        self.frame19 = Frame(Tk)
        self.frame20 = Frame(Tk)
        self.frame21 = Frame(Tk)
        self.frame22 = Frame(Tk)
        self.frame23 = Frame(Tk)
        self.frame24 = Frame(Tk)
        self.frame1.pack()
        self.frame2.pack(pady = 5)
        self.frame3.pack(pady = 5)
        self.frame4.pack(pady = 5)
        self.frame5.pack(pady = 5)
        self.frame6.pack(pady = 5)
        self.frame7.pack(pady = 5)
        self.frame8.pack(pady = 5)
        self.frame9.pack(pady = 5)
        self.frame10.pack(pady = 5)
        self.frame11.pack(pady = 5)
        self.frame12.pack(pady = 5)
        self.frame13.pack(pady = 5)
        self.frame14.pack(pady = 5)
        self.frame15.pack(pady = 5)
        self.frame16.pack(pady = 5)
        self.frame17.pack(pady = 5)
        self.frame18.pack(pady = 5)
        self.frame19.pack(pady = 5)
        self.frame20.pack(pady = 5)
        self.frame21.pack(pady = 5)
        self.frame22.pack(pady = 5)
        self.frame23.pack(pady = 5)
        self.frame24.pack(pady = 5)
        
        self.lb1 = Label(self.frame1, text = 'CONVERSOR DE TEMPERATURA')
        self.lb1['fg'] = 'black'
        self.lb1['font'] = ('Arial', 16, 'bold')
        self.lb1['height'] = 3 
        self.lb1.pack()
        
        self.lb2 = Label(self.frame2, text = 'Escolha a conversão que deseja realizar: ')
        self.lb2['fg'] = 'black'
        self.lb2['font'] = ('Arial', 14)
        self.lb2.pack()
        
        self.bt1 = Button(self.frame3, text = 'Graus Celsius para Kelvin', command = self.celsius_kelvin)
        self.bt1['bg'] = 'blue'
        self.bt1['fg'] = 'white'
        self.bt1['font'] = ('Arial', 12)
        self.bt1.focus_force()
        self.bt1.pack()
        
        self.bt2 = Button(self.frame4, text = 'Graus Celsius para Graus Fahrenheit', command = self.celsius_fahrenheit)
        self.bt2['bg'] = 'blue'
        self.bt2['fg'] = 'white'
        self.bt2['font'] = ('Arial', 12)
        self.bt2.pack()
        
        self.bt3 = Button(self.frame5, text = 'Graus Fahrenheit para Graus Celsius', command = self.fahrenheit_celsius)
        self.bt3['bg'] = 'blue'
        self.bt3['fg'] = 'white'
        self.bt3['font'] = ('Arial', 12)
        self.bt3.focus_force()
        self.bt3.pack()
        
        self.bt4 = Button(self.frame6, text = 'Graus Fahrenheit para Kelvin', command = self.fahrenheit_kelvin)
        self.bt4['bg'] = 'blue'
        self.bt4['fg'] = 'white'
        self.bt4['font'] = ('Arial', 12)
        self.bt4.focus_force()
        self.bt4.pack()
        
        self.bt5 = Button(self.frame7, text = 'Kelvin para Graus Celsius', command = self.kelvin_celsius)
        self.bt5['bg'] = 'blue'
        self.bt5['fg'] = 'white'
        self.bt5['font'] = ('Arial', 12)
        self.bt5.focus_force()
        self.bt5.pack()
        
        self.bt6 = Button(self.frame8, text = 'Kelvin para Graus Fahrenheit', command = self.kelvin_fahrenheit)
        self.bt6['bg'] = 'blue'
        self.bt6['fg'] = 'white'
        self.bt6['font'] = ('Arial', 12)
        self.bt6.focus_force()
        self.bt6.pack()
        
        self.principal = Menu(raiz)
        self.principal.add_command(label = 'Sobre o Programa', command = self.sobre)
        raiz.configure(menu = self.principal)
    
    def celsius_kelvin(self):
        
        #Recebe a temperatura em Celsius para converter em Kelvin
        self.lb3 = Label(self.frame9, text = 'Informe a temperatura em Graus Celsius (°C): ')
        self.lb3['fg'] = 'black'
        self.lb3['font'] = ('Arial', 12)
        self.lb3.pack(side = LEFT)
        self.celsius_kelvin = Entry(self.frame9)
        self.celsius_kelvin['width'] = 5
        self.celsius_kelvin['font'] = ('Arial', 12)
        self.celsius_kelvin.focus_force()
        self.celsius_kelvin.pack(side = LEFT)
        
        #Botão de converter
        self.bt7 = Button(self.frame10, text = 'CONVERTER', command = self.conversao1)
        self.bt7['bg'] = 'blue'
        self.bt7['fg'] = 'white'
        self.bt7['font'] = ('Arial', 12)
        self.bt7.focus_force()
        self.bt7.pack()
        
    def conversao1(self):
        
        #Convertendo Celsius para Kelvin
        try:
            t = float(self.celsius_kelvin.get())
        except:
            t < -273.15
        self.q = (t+273.15)
        
        #Escrevendo o resultado
        self.lb4 = Label(self.frame11, text = f'A temperatura em Kelvin é {self.q:.2f}K')
        self.lb4['fg'] = 'black'
        self.lb4['font'] = ('Arial', 12, 'bold')
        self.lb4.pack()
        
    def celsius_fahrenheit(self):
        
        #Recebe a temperatura em Celsius para converter em Fahrenheit
        self.lb5 = Label(self.frame12, text = 'Informe a temperatura em Graus Celsius (°C): ')
        self.lb5['fg'] = 'black'
        self.lb5['font'] = ('Arial', 12)
        self.lb5.pack(side = LEFT)
        self.celsius_fahrenheit = Entry(self.frame12)
        self.celsius_fahrenheit['width'] = 5
        self.celsius_fahrenheit['font'] = ('Arial', 12)
        self.celsius_fahrenheit.focus_force()
        self.celsius_fahrenheit.pack(side = LEFT)
        
        #Botão de converter
        self.bt8 = Button(self.frame13, text = 'CONVERTER', command = self.conversao2)
        self.bt8['bg'] = 'blue'
        self.bt8['fg'] = 'white'
        self.bt8['font'] = ('Arial', 12)
        self.bt8.focus_force()
        self.bt8.pack()
        
    def conversao2(self):
        
        #Convertendo Celsius para Fahrenheit
        try:
            t = float(self.celsius_fahrenheit.get())
        except:
            t < -273.15
        self.q = ((t*9/5)+32)
        
        #Escrevendo o resultado
        self.lb6 = Label(self.frame14, text = f'A temperatura em Graus Fahrenheit é {self.q:.2f}°F')
        self.lb6['fg'] = 'black'
        self.lb6['font'] = ('Arial', 12, 'bold')
        self.lb6.pack()
        
    def fahrenheit_celsius(self):
        
        #Recebe a temperatura em Fahrenheit para converter em Celsius
        self.lb7 = Label(self.frame15, text = 'Informe a temperatura em Graus Fahrenheit (°F): ')
        self.lb7['fg'] = 'black'
        self.lb7['font'] = ('Arial', 12)
        self.lb7.pack(side = LEFT)
        self.fahrenheit_celsius = Entry(self.frame15)
        self.fahrenheit_celsius['width'] = 5
        self.fahrenheit_celsius['font'] = ('Arial', 12)
        self.fahrenheit_celsius.focus_force()
        self.fahrenheit_celsius.pack(side = LEFT)
        
        #Botão de converter
        self.bt9 = Button(self.frame16, text = 'CONVERTER', command = self.conversao3)
        self.bt9['bg'] = 'blue'
        self.bt9['fg'] = 'white'
        self.bt9['font'] = ('Arial', 12)
        self.bt9.focus_force()
        self.bt9.pack()
        
    def conversao3(self):
        
        #Convertendo Fahrenheit para Celsius
        try:
            t = float(self.fahrenheit_celsius.get())
        except:
            t < -459,67
        self.q = ((t-32)*5/9)
        
        #Escrevendo o resultado
        self.lb8 = Label(self.frame17, text = f'A temperatura em Graus Celsius é {self.q:.2f}°C')
        self.lb8['fg'] = 'black'
        self.lb8['font'] = ('Arial', 12, 'bold')
        self.lb8.pack()
        
    def fahrenheit_kelvin(self):
        
        #Recebe a temperatura em Fahrenheit para converter em Kelvin
        self.lb9 = Label(self.frame18, text = 'Informe a temperatura em Graus Fahrenheit (°F): ')
        self.lb9['fg'] = 'black'
        self.lb9['font'] = ('Arial', 12)
        self.lb9.pack(side = LEFT)
        self.fahrenheit_kelvin = Entry(self.frame18)
        self.fahrenheit_kelvin['width'] = 5
        self.fahrenheit_kelvin['font'] = ('Arial', 12)
        self.fahrenheit_kelvin.focus_force()
        self.fahrenheit_kelvin.pack(side = LEFT)
        
        #Botão de converter
        self.bt10 = Button(self.frame19, text = 'CONVERTER', command = self.conversao4)
        self.bt10['bg'] = 'blue'
        self.bt10['fg'] = 'white'
        self.bt10['font'] = ('Arial', 12)
        self.bt10.focus_force()
        self.bt10.pack()
        
    def conversao4(self):
        
        #Convertendo Fahrenheit para Kelvin
        try:
            t = float(self.fahrenheit_kelvin.get())
        except:
            t < -459,67
        self.q = (((t-32)*10/18)+273.15)
        
        #Escrevendo o resultado
        self.lb10 = Label(self.frame20, text = f'A temperatura em Kelvin é {self.q:.2f}K')
        self.lb10['fg'] = 'black'
        self.lb10['font'] = ('Arial', 12, 'bold')
        self.lb10.pack()
        
    def kelvin_celsius(self):
        
        #Recebe a temperatura em Kelvin para converter em Celsius
        self.lb11 = Label(self.frame21, text = 'Informe a temperatura em Kelvin (K): ')
        self.lb11['fg'] = 'black'
        self.lb11['font'] = ('Arial', 12)
        self.lb11.pack(side = LEFT)
        self.kelvin_celsius = Entry(self.frame21)
        self.kelvin_celsius['width'] = 5
        self.kelvin_celsius['font'] = ('Arial', 12)
        self.kelvin_celsius.focus_force()
        self.kelvin_celsius.pack(side = LEFT)
        
        #Botão de converter
        self.bt11 = Button(self.frame22, text = 'CONVERTER', command = self.conversao5)
        self.bt11['bg'] = 'blue'
        self.bt11['fg'] = 'white'
        self.bt11['font'] = ('Arial', 12)
        self.bt11.focus_force()
        self.bt11.pack()
        
    def conversao5(self):
        
        #Convertendo Kelvin para Celsius
        try:
            t = float(self.kelvin_celsius.get())
        except:
            t < 0
        self.q = (t-273.15)
        
        #Escrevendo o resultado
        self.lb12 = Label(self.frame23, text = f'A temperatura em Graus Celsius é {self.q:.2f}°C')
        self.lb12['fg'] = 'black'
        self.lb12['font'] = ('Arial', 12, 'bold')
        self.lb12.pack()
        
    def kelvin_fahrenheit(self):
        
        #Recebe a temperatura em Kelvin para converter em Fahrenheit
        self.lb13 = Label(self.frame22, text = 'Informe a temperatura em Kelvin (K): ')
        self.lb13['fg'] = 'black'
        self.lb13['font'] = ('Arial', 12)
        self.lb13.pack(side = LEFT)
        self.kelvin_fahrenheit = Entry(self.frame22)
        self.kelvin_fahrenheit['width'] = 5
        self.kelvin_fahrenheit['font'] = ('Arial', 12)
        self.kelvin_fahrenheit.focus_force()
        self.kelvin_fahrenheit.pack(side = LEFT)
        
        #Botão de converter
        self.bt12 = Button(self.frame23, text = 'CONVERTER', command = self.conversao6)
        self.bt12['bg'] = 'blue'
        self.bt12['fg'] = 'white'
        self.bt12['font'] = ('Arial', 12)
        self.bt12.focus_force()
        self.bt12.pack()
        
    def conversao6(self):
        
        #Convertendo Kelvin para Fahrenheit
        try:
            t = float(self.kelvin_fahrenheit.get())
        except:
            t < 0
        self.q = (((t-273.15)*18/10)+32)
        
        #Escrevendo o resultado
        self.lb14 = Label(self.frame24, text = f'A temperatura em Graus Fahrenheit é {self.q:.2f}°F')
        self.lb14['fg'] = 'black'
        self.lb14['font'] = ('Arial', 12, 'bold')
        self.lb14.pack()
    
    def sobre(self):
        raiz1 = Tk()
        Janela2(raiz1)
        raiz1.mainloop()
    def delete(self):
        raiz.destroy()
        
raiz = Tk()
a = Janela(raiz)
raiz.title('Conversor de Temperatura')
raiz.mainloop()

# %%
class Janela2:
    def __init__(self, Tk):
        self.frame1 = Frame(Tk)
        self.frame2 = Frame(Tk)
        self.frame3 = Frame(Tk)
        self.frame4 = Frame(Tk)
        self.frame1.pack()
        self.frame2.pack()
        self.frame3.pack()
        self.frame4.pack()
        
        self.label = Label(self.frame1, text = 'Conversor de Temperatura Versão 1.0')
        
        self.lb1 = Label(self.frame2, text = 'Este Programa realiza conversões entre as três principais formas de se medir temperatura: Graus Celsius, Graus Fahrenheit e Kelvin.')
        self.lb2 = Label(self.frame2, text = '')
        self.lb3 = Label(self.frame4, text = 'Desenvolvido por Iury Costa Barros e Sávio Aparecido dos Santos Pereira.')
        self.label.pack()
        self.lb1.pack()
        self.lb2.pack()
        self.lb3.pack()
